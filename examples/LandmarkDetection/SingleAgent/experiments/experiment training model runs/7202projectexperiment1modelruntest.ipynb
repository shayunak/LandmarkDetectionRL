# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#experiment 1: Model runs
#NOTE: Any run with less than 10 distance error values is deemed inconclusive (it will not converge)
#experiment1_25000 = np.array([41.78516483155236, 62.5859409132754]) #25000
#experiment1_50000 = np.array([5.385164807134504, 4.47213595499958, 3.7416573867739413, 4.898979485566356]) #50000
experiment1_75000 = np.array([71.19691004531025, 132.9962405483704, 95.81753492967766, 99.51884243699783, 112.25862995778988, 104.78549517943789, 78.7273777030583, 115.06954418958998, 116.46887996370532, 106.17438485811914]) #75000
experiment1_100000 = np.array([1.0, 2.23606797749979, 1.7320508075688772, 1.7320508075688772, 2.23606797749979, 1.4142135623730951, 2.23606797749979, 1.7320508075688772, 1.0, 1.4142135623730951]) #100000
experiment1_125000 = np.array([138.5640646055102, 139.27311298308803, 138.84523758487362, 138.51714695300362, 149.89996664442592, 136.09922850626305, 132.24598292575845, 133.79461872586654, 136.2827942184926, 147.59403781996073]) #125000
experiment1_150000 = np.array([3.1622776601683795, 3.605551275463989, 3.3166247903554, 3.7416573867739413, 5.0, 5.0990195135927845, 5.0, 7.280109889280518, 4.0, 4.358898943540674]) #150000
experiment1_175000 = np.array([3.7416573867739413, 3.0, 4.242640687119285, 2.8284271247461903, 3.4641016151377544, 3.605551275463989, 3.605551275463989, 8.18535277187245, 5.0, 4.58257569495584]) #175000
experiment1_200000 = np.array([1.7320508075688772, 1.7320508075688772, 2.449489742783178, 2.449489742783178, 2.449489742783178, 3.1622776601683795, 3.0, 3.0, 1.4142135623730951, 3.0]) #200000
experiment1_225000 = np.array([1.7320508075688772, 2.449489742783178, 1.7320508075688772, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.449489742783178, 2.23606797749979, 2.449489742783178, 1.4142135623730951]) #225000
experiment1_250000 = np.array([5.0990195135927845, 3.0, 4.123105625617661, 4.47213595499958, 3.7416573867739413, 4.123105625617661, 4.0, 3.1622776601683795, 4.123105625617661, 3.1622776601683795]) #250000

# %%
modelRunAmounts = [75000, 100000, 125000, 150000, 175000, 200000, 225000, 250000]
experiment1_all = [experiment1_75000, experiment1_100000, experiment1_125000, experiment1_150000, experiment1_175000, experiment1_200000, experiment1_225000, experiment1_250000]

# %%
experimentAverages = []
for experiment in experiment1_all:
    experimentLength = len(experiment)
    experimentSum = np.sum(experiment)
    experimentAverage = experimentSum/experimentLength
    experimentAverages.append(experimentAverage)

# %%
experimentAverages
# Out:
# [np.float64(103.30138398120566),
#  np.float64(1.6732783479952194),
#  np.float64(139.11161909672427),
#  np.float64(4.456413945917569),
#  np.float64(4.225585783153344),
#  np.float64(2.4389062066028764),
#  np.float64(2.1171056315859547),
#  np.float64(3.900668505255605)]

# %%
plt.plot(modelRunAmounts, experimentAverages)
plt.title('Average Distance Error for Varying Amounts of Model Runs')
plt.xlabel('Model Runs')
plt.ylabel('Average Distance Error')
# Out:
# Text(0, 0.5, 'Average Distance Error')
